# %%
import numpy as np
from PyAstronomy import pyasl
import matplotlib.pyplot as plt
import matplotlib.animation as animation

#Latex font
import matplotlib as mpl
from matplotlib import rc
plt.rc('text', usetex=True)
plt.rc('font', family='serif',size=16)

# %%
orbit = pyasl.KeplerEllipse(a=8.19, per=9000 , e=0.39, tau = 2453020, Omega=0.0, i=0.0, w=-78)
t = np.linspace(0, 9000, 500)
#print(t)
pos_a = orbit.xyzPos(t)
#print(pos)

# %%
fig = plt.subplots(1, 1, sharex=True, sharey=False, figsize=(15, 5), tight_layout=True)

plt.plot(0, 0, 'bo', markersize=9, label="DP Leo")
plt.plot(pos_a[0, 1], pos_a[0, 0], 'r*', markersize=9, label="Periapsis")
plt.plot(pos_a[::, 1], pos_a[::, 0], 'r-', label="planet Trajectory with P = 9000 days")

# Put a legend to the right of the current axis
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('X (AU)')
plt.ylabel('Y (AU)')
#plt.legend(loc="best")
#plt.title('Orbital Simulation')
plt.show()

# %%
orbit = pyasl.KeplerEllipse(a=8.19, per=10000 , e=0.39, tau = 2453020, Omega=0.0, i=0.0, w=-78)
t = np.linspace(0, 10000, 500)
#print(t)
pos_b = orbit.xyzPos(t)
#print(pos)

# %%
fig = plt.subplots(1, 1, sharex=True, sharey=False, figsize=(15, 5), tight_layout=True)

plt.plot(0, 0, 'bo', markersize=9, label="DP Leo")
plt.plot(pos_a[0, 1], pos_a[0, 0], 'r*', markersize=9, label="Periapsis")
plt.plot(pos_a[::, 1], pos_a[::, 0], 'r-', label="planet Trajectory with P = 9000 days")

plt.plot(pos_b[::, 1], pos_b[::, 0], 'g-', label="planet Trajectory with P = 10000 days")
plt.plot(pos_b[0, 1], pos_b[0, 0], 'g*', markersize=9)

# Put a legend to the right of the current axis
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('X (AU)')
plt.ylabel('Y (AU)')
#plt.legend(loc="best")
#plt.title('Orbital Simulation')
plt.show()

# %%
orbit = pyasl.KeplerEllipse(a=8.19, per=11000 , e=0.39, tau = 2453020, Omega=0.0, i=0.0, w=-78)
t = np.linspace(0, 11000, 500)
#print(t)
pos_c = orbit.xyzPos(t)
#print(pos)

# %%
fig = plt.subplots(1, 1, sharex=True, sharey=False, figsize=(15, 5), tight_layout=True)

plt.plot(0, 0, 'bo', markersize=9, label="DP Leo")
plt.plot(pos_a[0, 1], pos_a[0, 0], 'r*', markersize=9, label="Periapsis")
plt.plot(pos_a[::, 1], pos_a[::, 0], 'r-', label="planet Trajectory with P = 9000 days")

plt.plot(pos_b[::, 1], pos_b[::, 0], 'g-', label="planet Trajectory with P = 10000 days")
plt.plot(pos_b[0, 1], pos_b[0, 0], 'g*', markersize=9)

plt.plot(pos_c[::, 1], pos_c[::, 0], 'b-', label="planet Trajectory with P = 11000 days")
plt.plot(pos_c[0, 1], pos_c[0, 0], 'b*', markersize=9)

# Put a legend to the right of the current axis
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('X (AU)')
plt.ylabel('Y (AU)')
#plt.legend(loc="best")
#plt.title('Orbital Simulation')
plt.show()

# %%
orbit = pyasl.KeplerEllipse(a=8.19, per=12000 , e=0.39, tau = 2453020, Omega=0.0, i=0.0, w=-78)
t = np.linspace(0, 12000, 500)
#print(t)
pos_d = orbit.xyzPos(t)
#print(pos)

# %%
fig = plt.subplots(1, 1, sharex=True, sharey=False, figsize=(15, 5), tight_layout=True)

plt.plot(0, 0, 'bo', markersize=9, label="DP Leo")
plt.plot(pos_a[0, 1], pos_a[0, 0], 'r*', markersize=9, label="Periapsis")
plt.plot(pos_a[::, 1], pos_a[::, 0], 'r-', label="planet Trajectory with P = 9000 days")

plt.plot(pos_b[::, 1], pos_b[::, 0], 'g-', label="planet Trajectory with P = 10000 days")
plt.plot(pos_b[0, 1], pos_b[0, 0], 'g*', markersize=9)

plt.plot(pos_c[::, 1], pos_c[::, 0], 'b-', label="planet Trajectory with P = 11000 days")
plt.plot(pos_c[0, 1], pos_c[0, 0], 'b*', markersize=9)

plt.plot(pos_d[::, 1], pos_d[::, 0], 'y-', label="planet Trajectory with P = 12000 days")
plt.plot(pos_d[0, 1], pos_d[0, 0], 'y*', markersize=9)



# Put a legend to the right of the current axis
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('X (AU)')
plt.ylabel('Y (AU)')
#plt.legend(loc="best")
#plt.title('Orbital Simulation')
plt.show()

# %%
orbit = pyasl.KeplerEllipse(a=8.19, per=13000 , e=0.39, tau = 2453020, Omega=0.0, i=0.0, w=-78)
t = np.linspace(0, 13000, 500)
#print(t)
pos_e = orbit.xyzPos(t)
#print(pos)

# %%
fig = plt.subplots(1, 1, sharex=True, sharey=False, figsize=(15, 5), tight_layout=True)

plt.plot(0, 0, 'bo', markersize=9, label="DP Leo")
plt.plot(pos_a[0, 1], pos_a[0, 0], 'r*', markersize=9, label="Periapsis")
plt.plot(pos_a[::, 1], pos_a[::, 0], 'r-', label="Planet trajectory with P = 9000 days")

plt.plot(pos_b[0, 1], pos_b[0, 0], 'g*', markersize=9, label="Periapsis")
plt.plot(pos_b[::, 1], pos_b[::, 0], 'g-', label="Planet trajectory with P = 10000 days")

plt.plot(pos_c[0, 1], pos_c[0, 0], 'b*', markersize=9, label="Periapsis")
plt.plot(pos_c[::, 1], pos_c[::, 0], 'b-', label="Planet trajectory with P = 11000 days")

plt.plot(pos_d[0, 1], pos_d[0, 0], 'y*', markersize=9, label="Periapsis")
plt.plot(pos_d[::, 1], pos_d[::, 0], 'y-', label="Planet trajectory with P = 12000 days")

plt.plot(pos_e[0, 1], pos_e[0, 0], 'm*', markersize=9, label="Periapsis")
plt.plot(pos_e[::, 1], pos_e[::, 0], 'm-', label="Planet trajectory with P = 13000 days")


# Put a legend to the right of the current axis
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('X (AU)')
plt.ylabel('Y (AU)')
#plt.legend(loc="best")
#plt.title('Orbital Simulation')
plt.savefig("2D_orbit_modeling_P.pdf", format='pdf', dpi=1200)
plt.show()
